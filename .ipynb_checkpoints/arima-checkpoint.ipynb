# %% [markdown]
# # 数据准备

# %% [markdown]
# ## 导入库

# %%
import tushare as ts
pro = ts.pro_api('647f6840944a4425d46c97c08cf20af6b656bb79673bd1635ebdf0ce')
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 读取股票历史价格

# %%
data=pro.query('daily', ts_code='000598.SZ', start_date='20190117', end_date='20210903')
df = pd.DataFrame(data)
df.to_csv('XRHJ000598.csv')
df_000598 = pd.DataFrame(pd.read_csv('XRHJ000598.csv'))
Stock_close = df_000598['close']
Stock_close=Stock_close.reindex(Stock_close.index[::-1])

# %% [markdown]
# ## 绘制价格曲线

# %%
plt.figure()
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
 
plt.plot(list(range(len(Stock_close))), Stock_close, color='r')
plt.xlabel('交易日期：2019-01-17至2021-09-03', fontsize=14)
plt.ylabel('收盘价', fontsize=14)
plt.title('股票000598收盘价隔走势图', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# ## 分割数据

# %%
Stock_XRHJ = pd.read_csv('XRHJ000598.csv',index_col = 'trade_date',parse_dates=['trade_date'])
df = pd.DataFrame(Stock_XRHJ)
df=df.iloc[::-1]

#1.数据准备
df.index = pd.to_datetime(df.index)
sub    = df['2019-01':'2021-08']['close']
train  = df['2019-01':'2020-12']['close']
test   = df['2021-01':'2021-08']['close']
plt.figure(figsize=(20,10))
plt.plot(sub)
plt.title('总数据 2019-01~2021-08', fontsize=10)
plt.grid()
plt.show()
plt.plot(train)
plt.title('训练数据 2019-01~2020-12', fontsize=10)
plt.grid()
plt.show()
plt.plot(test)
plt.title('测试数据 2021-01:2021-08', fontsize=10)
plt.grid()
plt.show()

# %%
df
# Out:
#             Unnamed: 0    ts_code  open  high   low  close  pre_close  change  \
# trade_date
# 2019-01-17         640  000598.SZ  4.18  4.18  4.14   4.15       4.17   -0.02
# 2019-01-18         639  000598.SZ  4.16  4.19  4.15   4.18       4.15    0.03
# 2019-01-21         638  000598.SZ  4.20  4.22  4.17   4.17       4.18   -0.01
# 2019-01-22         637  000598.SZ  4.17  4.21  4.16   4.18       4.17    0.01
# 2019-01-23         636  000598.SZ  4.17  4.20  4.15   4.19       4.18    0.01
# ...                ...        ...   ...   ...   ...    ...        ...     ...
# 2021-08-30           4  000598.SZ  5.50  5.51  5.35   5.44       5.47   -0.03
# 2021-08-31           3  000598.SZ  5.47  5.58  5.43   5.54       5.44    0.10
# 2021-09-01           2  000598.SZ  5.54  5.63  5.51   5.55       5.54    0.01
# 2021-09-02           1  000598.SZ  5.55  5.61  5.51   5.60       5.55    0.05
# 2021-09-03           0  000598.SZ  5.59  5.72  5.56   5.62       5.60    0.02
#
# ...

# %% [markdown]
# # 差分法分析

# %%
#2.差分法
df['Close_diff_1'] = df['close'].diff(1)#一阶差分
df['Close_diff_2'] = df['Close_diff_1'].diff(1)#二阶差分

fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(131)
ax1.plot(df['close'])
ax2 = fig.add_subplot(132)
ax2.plot(df['Close_diff_1'])
ax3 = fig.add_subplot(133)
ax3.plot(df['Close_diff_2'])
plt.show()

# %% [markdown]
# # ARIMA(p,d,q)中p,q的确定

# %%
import statsmodels.api as sm
 
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train, lags=20,ax=ax1)
ax1.xaxis.set_ticks_position('bottom')
fig.tight_layout()
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train, lags=20, ax=ax2)
ax2.xaxis.set_ticks_position('bottom')
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19952\2827973844.py in <module>
# ----> 1 import statsmodels.api as sm
#       2
#       3 fig = plt.figure(figsize=(12,8))
#       4 ax1 = fig.add_subplot(211)
#       5 fig = sm.graphics.tsa.plot_acf(train, lags=20,ax=ax1)
#
# D:\ANA\lib\site-packages\statsmodels\api.py in <module>
#      72 from . import datasets, distributions, iolib, regression, robust, tools
#      73 from .__init__ import test
# ---> 74 from .discrete.count_model import (
#      75     ZeroInflatedGeneralizedPoisson,
#      76     ZeroInflatedNegativeBinomialP,
#
# D:\ANA\lib\site-packages\statsmodels\discrete\count_model.py in <module>
#       7 import statsmodels.base.wrapper as wrap
#       8 import statsmodels.regression.linear_model as lm
# ...
